# %%
https://raw.githubusercontent.com/bendaizer/villebon-charpak-5.2/master/CC/cc6.csv

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

#Question 1
data = np.loadtxt("https://raw.githubusercontent.com/bendaizer/villebon-charpak-5.2/master/CC/cc6.csv")
print(data)

x = data[:,1]
y = data[:,2]
#print(x)
#print(y)

#Question 2
plt.hist(x)
plt.hist(y)
plt.show()

plt.scatter(x,y)
plt.show()


#Question 3
x = x.reshape(-1,1)
y = y.reshape(-1,1)
regr = linear_model.LinearRegression()
regr.fit(x, y)

#recuperer les coefficients
regr.coef_, regr.intercept_

#coefficient R²
print(regr.score(x,y))

residus = y - regr.predict(x)
plt.hist(residus, bins=100)
plt.show()
# Out:
# [[  1.      3.6    79.   ]
#  [  2.      1.8    54.   ]
#  [  3.      3.333  74.   ]
#  [  4.      2.283  62.   ]
#  [  5.      4.533  85.   ]
#  [  6.      2.883  55.   ]
#  [  7.      4.7    88.   ]
#  [  8.      3.6    85.   ]
#  [  9.      1.95   51.   ]
#  [ 10.      4.35   85.   ]
#  [ 11.      1.833  54.   ]
#  [ 12.      3.917  84.   ]
#  [ 13.      4.2    78.   ]
#  [ 14.      1.75   47.   ]
#  [ 15.      4.7    83.   ]
#  [ 16.      2.167  52.   ]
#  [ 17.      1.75   62.   ]
#  [ 18.      4.8    84.   ]
#  [ 19.      1.6    52.   ]
#  [ 20.      4.25   79.   ]
#  [ 21.      1.8    51.   ]
#  [ 22.      1.75   47.   ]
#  [ 23.      3.45   78.   ]
#  [ 24.      3.067  69.   ]
#  [ 25.      4.533  74.   ]
#  [ 26.      3.6    83.   ]
#  [ 27.      1.967  55.   ]
#  [ 28.      4.083  76.   ]
#  [ 29.      3.85   78.   ]
#  [ 30.      4.433  79.   ]
#  [ 31.      4.3    73.   ]
#  [ 32.      4.467  77.   ]
#  [ 33.      3.367  66.   ]
#  [ 34.      4.033  80.   ]
# ...
